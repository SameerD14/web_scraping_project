# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\hp\\Data Science With AI\\web_scraping_project\\amazon_laptops4.csv")

# %%
df.head()
# Out:
#                                                title   price       rating  \
# 0  HP Omnibook 3, Snapdragon X Processor 45 Tops ...  69,990          NaN
# 1  Dell 15 SmartChoice (Previously Inspiron), Int...  72,990          NaN
# 2  Lenovo V15 G4 AMD Athlon Silver 7120U Laptop 8...  44,999          NaN
# 3  Acer Smartchoice Aspire One, AMD Ryzen 3-7320U...  42,990  Pure Silver
# 4  Dell 15 (Previously Inspiron), R5-7520U Proces...  53,990          NaN
#
#     brand   ram storage   color   processor
# 0      HP  16GB   512GB  Silver  Apple M365
# 1    Dell  16GB     1TB  Silver       Intel
# 2  Lenovo   8GB   512GB  Silver         AMD
# 3    Acer   8GB   256GB  Silver  Apple A114
# 4    Dell   8GB   512GB   Black         NaN

# %%
# TO CHECK ROW AND COLUMNS
df.shape
# Out:
# (800, 8)

# %%
# CHECk columns NAMES
df.columns
# Out:
# Index(['title', 'price', 'rating', 'brand', 'ram', 'storage', 'color',
#        'processor'],
#       dtype='str')

# %%
# step 2 check basic Information about the dataset
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      800 non-null    str
#  1   price      794 non-null    str
#  2   rating     32 non-null     str
#  3   brand      800 non-null    str
#  4   ram        689 non-null    str
#  5   storage    664 non-null    str
#  6   color      626 non-null    str
#  7   processor  635 non-null    str
# dtypes: str(8)
# memory usage: 50.1 KB

# %%
# check missing values in the dataset
df.isnull().sum()
# Out:
# title          0
# price          6
# rating       768
# brand          0
# ram          111
# storage      136
# color        174
# processor    165
# dtype: int64

# %%
# clean the price column
df["price"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df["price"].head()
# Out:
# 0    69,990
# 1    72,990
# 2    44,999
# 3    42,990
# 4    53,990
# Name: price, dtype: str

# %%
df["price"].unique()
# Out:
# <StringArray>
# [  '69,990',   '72,990',   '44,999',   '42,990',   '53,990',   '87,990',
#    '67,990',   '73,990', '5,89,990',   '35,990',
#  ...
#    '64,810', '3,67,900',   '64,900', '1,67,490',   '27,490',   '83,465',
#    '47,990',   '43,699',   '57,490',   '62,490']
# Length: 218, dtype: str

# %%
df["price"] = df["price"].str.replace(",","")

# %%
df["price"]=pd.to_numeric(df["price"],errors="coerce")

# %%
df["price"]=df["price"].fillna(df["price"].mean())

# %%
df["price"].dtype
# Out:
# dtype('float64')

# %%
df["price"].isnull().sum()
# Out:
# np.int64(0)

# %%
# Now i want to clean rating columns

# %%
df["rating"].unique()
# Out:
# <StringArray>
# [                              nan,                     'Pure Silver',
#                           'Silver',                      'Steel Gray',
#                    'Get it faster',          'Silver RYZEN 7-7th Gen',
#                             'Blue',                    'Carbon Black',
#       'Cloud Grey - Ryzen 5 5500U',                     'Cool Silver',
#                    'Silver MSO'24',                      'Quiet Blue',
#                      'Mixed Black', 'Dark Shadow Gray - RTX 3050 6GB',
#     'Luna Grey|16GB | 512GB | 14"',              'Silver-13th Gen i5']
# Length: 16, dtype: str

# %%
df.isnull().sum()
# Out:
# title          0
# price          0
# rating       768
# brand          0
# ram          111
# storage      136
# color        174
# processor    165
# dtype: int64

# %%
df["rating"].value_counts()
# Out:
# rating
# Get it faster                      9
# Silver                             6
# Blue                               2
# Cool Silver                        2
# Quiet Blue                         2
# Dark Shadow Gray - RTX 3050 6GB    2
# Pure Silver                        1
# Steel Gray                         1
# Silver RYZEN 7-7th Gen             1
# Carbon Black                       1
# Cloud Grey - Ryzen 5 5500U         1
# Silver MSO'24                      1
# Mixed Black                        1
# Luna Grey|16GB | 512GB | 14"       1
# Silver-13th Gen i5                 1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      292 non-null    str
#  1   price      289 non-null    float64
#  2   rating     9 non-null      str
#  3   brand      292 non-null    str
#  4   ram        263 non-null    str
#  5   storage    244 non-null    str
#  6   color      254 non-null    str
#  7   processor  260 non-null    str
# dtypes: float64(1), str(7)
# memory usage: 18.4 KB

# %%
df["rating"].unique()
# Out:
# <StringArray>
# [                          nan,               'Get it faster',
#                       'Silver',                'Carbon Black',
#                   'Quiet Blue',                 'Cool Silver',
#  'Luna Grey {Core-5-24GB Ram}']
# Length: 7, dtype: str

# %%
df["rating"].value_counts(dropna=False)
# Out:
# rating
# NaN                            283
# Get it faster                    4
# Silver                           1
# Carbon Black                     1
# Quiet Blue                       1
# Cool Silver                      1
# Luna Grey {Core-5-24GB Ram}      1
# Name: count, dtype: int64

# %%
df["rating"].isna().sum()
# Out:
# np.int64(283)

# %%
# Then we can decide whether to keep those 7 missing values, remove them, or fill them.
df["rating"].describe()
# Out:
# count                 9
# unique                6
# top       Get it faster
# freq                  4
# Name: rating, dtype: object

# %%
# df["rating"] = df["rating"].fillna(df["rating"].isna().mean() * 100)
df["rating"].isna().sum()
# Out:
# np.int64(283)

# %%
df["rating"]=pd.to_numeric(df["rating"], errors='coerce')

# %%
df["rating"] = df["rating"].fillna(df["rating"].median())

# %%
df["rating"].isna().sum()
# Out:
# np.int64(292)

# %%
df["rating"].value_counts(dropna=False)
# Out:
# rating
# NaN    292
# Name: count, dtype: int64

# %%
df["brand"].unique()
# Out:
# <StringArray>
# [     'ASUS',        'HP',    'Lenovo',      'Dell',      'Acer',   'Samsung',
#    'Unknown',     'Apple',      'acer',       'MSI',      'DELL', 'Primebook',
#    'MaxBook']
# Length: 13, dtype: str

# %%
df["brand"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["brand"]=df["brand"].replace("acer","Acer")

# %%
df["brand"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df["ram"].unique()
# Out:
# <StringArray>
# ['16GB', '24GB', '8GB', '36GB', 'RAM', '48GB', '32GB']
# Length: 7, dtype: str

# %%
df["rating"].unique()
# Out:
# array([3.2, 4.6, 4.8, 4.7, 3.6, 3.9, 2.4, 3.8, 4.5, 5. , 4.3, 4.1, 2. ,
#        2.8, 4. , 4.2, 3.3])

# %%
df["ram"].unique()
# Out:
# <StringArray>
# ['16GB', '24GB', '8GB', '36GB', 'RAM', '48GB', '32GB']
# Length: 7, dtype: str

# %%
df["ram"] = df["ram"].str.extract(r"(\d+)").astype(float)

# %%
import numpy as np

df["ram"] = df["ram"].replace("RAM", np.nan)

# %%
df["ram"].unique()
# Out:
# array([16., 24.,  8., 36., nan, 48., 32.])

# %%
df["ram"] = df["ram"].fillna(df["ram"].median())

# %%
df["ram"].unique()
# Out:
# array([16., 24.,  8., 36., 48., 32.])

# %%
df.isna().sum()
# Out:
# title          0
# price          0
# rating         0
# brand          0
# ram            0
# storage        3
# color        153
# processor    458
# dtype: int64

# %%
df["ram"].dtype
# Out:
# dtype('float64')

# %%
df["storage"].unique()
# Out:
# <StringArray>
# ['512GB', '2TB', '1TB', nan, '256GB']
# Length: 5, dtype: str

# %%
def convert_storage(x):
    if pd.isna(x):
        return x
    if "TB" in x:
        return float(x.replace("TB", "")) * 1024
    return float(x.replace("GB", ""))

df["storage"] = df["storage"].apply(convert_storage)

# %%
df["storage"].unique()
# Out:
# array([ 512., 2048., 1024.,   nan,  256.])

# %%
df["storage"].isna().sum()
# Out:
# np.int64(3)

# %%
df[df["storage"].isna()]
# Out:
#                                                  title   price  rating brand  \
# 3    Acer Aspire 3 Laptop A325-42 | 15.6" (39.6 cm)...   40999     4.7  Acer
# 539  ASUS Vivobook 15 (2026),Intel Core 5 320 (Seri...  101990     4.7  ASUS
# 694  ASUS Vivobook 15 (2026),Intel Core 5 320 (Seri...  101990     4.7  ASUS
#
#       ram  storage color processor
# 3     8.0      NaN  Gray       AMD
# 539  16.0      NaN  Blue     Intel
# 694  16.0      NaN  Blue     Intel

# %%
df.loc[[3, 539, 694], "title"]
# Out:
# 3      Acer Aspire 3 Laptop A325-42 | 15.6" (39.6 cm)...
# 539    ASUS Vivobook 15 (2026),Intel Core 5 320 (Seri...
# 694    ASUS Vivobook 15 (2026),Intel Core 5 320 (Seri...
# Name: title, dtype: str

# %%
df["storage"] = df["storage"].fillna(df["storage"].median())

# %%
df["storage"].unique()
# Out:
# array([ 512., 2048., 1024.,  256.])

# %%
df["storage"].dtype
# Out:
# dtype('float64')

# %%
# clean the color
df["color"].unique()
# Out:
# <StringArray>
# ['Silver', nan, 'Gray', 'Black', 'Blue', 'Grey', 'Indigo']
# Length: 7, dtype: str

# %%
import random

apple_colors = ["Sky Blue", "Silver", "Starlight", "Midnight"]

for i in df.index:
    if df.loc[i, "brand"] == "Apple" and pd.isna(df.loc[i, "color"]):
        df.loc[i, "color"] = random.choice(apple_colors)

# %%
df["color"].unique()
# Out:
# <StringArray>
# [   'Silver', 'Starlight',      'Gray',  'Sky Blue',     'Black',      'Blue',
#   'Midnight',      'Grey',    'Indigo',         nan]
# Length: 10, dtype: str

# %%
df["color"].value_counts(dropna=False)
# Out:
# color
# Silver       376
# Black        134
# Starlight     39
# Blue          39
# Midnight      37
# Sky Blue      35
# Grey          19
# Indigo        11
# Gray           3
# NaN            3
# Name: count, dtype: int64

# %%
df[df["color"].isna()]
# Out:
#                                                  title  price  rating   brand  \
# 452  Lenovo ThinkPad E14 AMD Ryzen 7 7735HS (16GB R...  97990     2.8  Lenovo
# 467  Lenovo ThinkPad E14 AMD Ryzen 7 7735HS (16GB R...  97990     2.8  Lenovo
# 591  ASUS Vivobook 15 (2026),Intel Core 3 304 (Seri...  74990     4.7    ASUS
#
#       ram  storage color processor
# 452  16.0    512.0   NaN       AMD
# 467  16.0    512.0   NaN       AMD
# 591   8.0    512.0   NaN     Intel

# %%
df["color"]=df["color"].fillna("Black")

# %%
df[df["color"].isna()]
# Out:
# Empty DataFrame
# Columns: [title, price, rating, brand, ram, storage, color, processor]
# Index: []

# %%
df["color"].unique()
# Out:
# <StringArray>
# [   'Silver', 'Starlight',      'Gray',  'Sky Blue',     'Black',      'Blue',
#   'Midnight',      'Grey',    'Indigo']
# Length: 9, dtype: str

# %%
df["processor"].unique()
# Out:
# <StringArray>
# ['Snapdragon', nan, 'AMD', 'Intel']
# Length: 4, dtype: str

# %%
df["processor"].value_counts(dropna=False)
# Out:
# processor
# NaN           458
# Snapdragon    108
# Intel         108
# AMD            22
# Name: count, dtype: int64

# %%
# Out:
#                price
# count     292.000000
# mean   107715.269896
# std    118450.574361
# min     19990.000000
# 25%     49990.000000
# 50%     69990.000000
# 75%     83490.000000
# max    589990.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      292 non-null    str
#  1   price      292 non-null    float64
#  2   rating     9 non-null      str
#  3   brand      292 non-null    str
#  4   ram        263 non-null    str
#  5   storage    244 non-null    str
#  6   color      254 non-null    str
#  7   processor  260 non-null    str
# dtypes: float64(1), str(7)
# memory usage: 18.4 KB
